# %%
import pandas as pd

# %%
data_csv = "static/data/data-1605986563217.csv"
data_df = pd.read_csv(data_csv)
data_df.head()
# Out:
#   date_modified  positive  hospitalizedCumulative     death  recovered
# 0    2020-11-17  11209335                524678.0  239835.0  4294743.0
# 1    2020-11-16  11052613                520763.0  238280.0  4245304.0
# 2    2020-11-15  10903745                517615.0  237643.0  4185979.0
# 3    2020-11-14  10759311                515739.0  236966.0  4149020.0
# 4    2020-11-13  10595771                512274.0  235654.0  4095749.0

# %%
data_df = data_df.set_index("date_modified")
data_df
# Out:
#                positive  hospitalizedCumulative     death  recovered
# date_modified
# 2020-11-17     11209335                524678.0  239835.0  4294743.0
# 2020-11-16     11052613                520763.0  238280.0  4245304.0
# 2020-11-15     10903745                517615.0  237643.0  4185979.0
# 2020-11-14     10759311                515739.0  236966.0  4149020.0
# 2020-11-13     10595771                512274.0  235654.0  4095749.0
# ...                 ...                     ...       ...        ...
# 2020-01-26            0                     NaN       NaN        NaN
# 2020-01-25            0                     NaN       NaN        NaN
# 2020-01-24            0                     NaN       NaN        NaN
# 2020-01-23            0                     NaN       NaN        NaN
# 2020-01-22            0                     NaN       NaN        NaN
#
# [301 rows x 4 columns]

# %%
data_html = data_df.to_html()

# %%
print(data_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>positive</th>
#       <th>hospitalizedCumulative</th>
#       <th>death</th>
#       <th>recovered</th>
#     </tr>
#     <tr>
#       <th>date_modified</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2020-11-17</th>
#       <td>11209335</td>
#       <td>524678.0</td>
#       <td>239835.0</td>
#       <td>4294743.0</td>
#     </tr>
#     <tr>
#       <th>2020-11-16</th>
#       <td>11052613</td>
#       <td>520763.0</td>
#       <td>238280.0</td>
#       <td>4245304.0</td>
#     </tr>
#     <tr>
#       <th>2020-11-15</th>
#       <td>10903745</td>
#       <td>517615.0</td>
#       <td>237643.0</td>
#       <td>4185979.0</td>
#     </tr>
#     <tr>
#       <th>2020-11-14</th>
#       <td>10759311</td>
#       <td>515739.0</td>
#       <td>236966.0</td>
#       <td>4149020.0</td>
# ...
