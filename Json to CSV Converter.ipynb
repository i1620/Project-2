# %%
import pandas as pd
import json
import datetime as datetime

# %%
json_file = pd.read_json("data_sources/national_data.json")
json_file.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20201113      56  10588169  133262737  12010.0                68516.0
# 1  20201112      56  10417836  132049982  11385.0                67096.0
# 2  20201111      56  10267310  131040557  11287.0                65373.0
# 3  20201110      56  10122811  130048210   8579.0                61964.0
# 4  20201109      56   9991822  129109794  23458.0                59275.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                511397.0         13132.0          26997.0
# 1                507933.0         12796.0          26803.0
# 2                504015.0         12518.0          26584.0
# 3                500692.0         11952.0          26335.0
# 4                496746.0         11533.0          26087.0
#
#    onVentilatorCurrently  ...  totalTestResults          lastModified total  \
# 0                 3769.0  ...         164039849  2020-11-13T24:00:00Z     0
# 1                 3622.0  ...         162356169  2020-11-12T24:00:00Z     0
# 2                 3367.0  ...         160865743  2020-11-11T24:00:00Z     0
# 3                 3205.0  ...         159483885  2020-11-10T24:00:00Z     0
# 4                 3110.0  ...         158246520  2020-11-09T24:00:00Z     0
#
#    posNeg  deathIncrease  hospitalizedIncrease negativeIncrease  \
# 0       0           1301                  3464          1212755
# 1       0           1104                  3918          1009425
# 2       0           1565                  3323           992347
# 3       0           1347                  3946           938416
# 4       0            580                  2301          1224702
#
#    positiveIncrease  totalTestResultsIncrease  \
# 0            170333                   1683680
# 1            150526                   1490426
# 2            144499                   1381858
# 3            130989                   1237365
# 4            118708                   1518878
#
#                                        hash
# 0  cc4616ee0c98a8684efedbed10805664f0d865f1
# 1  e2701845e30d0152936845c12a4297cd916b0582
# 2  e55a31c7d307ec4920373ddce73c6337367b20ca
# 3  547d47494acfdd4002a96aa3a8f002454bbddd4a
# 4  5036a05337f039204f1fb11d603cdb964e8c60c0
#
# [5 rows x 25 columns]

# %%
json_file.dtypes
# Out:
# date                             int64
# state                           object
# positive                       float64
# probableCases                  float64
# negative                       float64
# pending                        float64
# totalTestResultsSource          object
# totalTestResults               float64
# hospitalizedCurrently          float64
# hospitalizedCumulative         float64
# inIcuCurrently                 float64
# inIcuCumulative                float64
# onVentilatorCurrently          float64
# onVentilatorCumulative         float64
# recovered                      float64
# dataQualityGrade                object
# lastUpdateEt                    object
# dateModified                    object
# checkTimeEt                     object
# death                          float64
# hospitalized                   float64
# dateChecked                     object
# totalTestsViral                float64
# positiveTestsViral             float64
# negativeTestsViral             float64
# positiveCasesViral             float64
# deathConfirmed                 float64
# deathProbable                  float64
# totalTestEncountersViral       float64
# totalTestsPeopleViral          float64
# totalTestsAntibody             float64
# positiveTestsAntibody          float64
# negativeTestsAntibody          float64
# totalTestsPeopleAntibody       float64
# positiveTestsPeopleAntibody    float64
# negativeTestsPeopleAntibody    float64
# totalTestsPeopleAntigen        float64
# positiveTestsPeopleAntigen     float64
# totalTestsAntigen              float64
# positiveTestsAntigen           float64
# fips                             int64
# positiveIncrease                 int64
# negativeIncrease                 int64
# total                            int64
# totalTestResultsIncrease         int64
# posNeg                           int64
# deathIncrease                    int64
# hospitalizedIncrease             int64
# hash                            object
# commercialScore                  int64
# negativeRegularScore             int64
# negativeScore                    int64
# positiveScore                    int64
# score                            int64
# grade                           object
# date_modified                   object
# dtype: object

# %%
json_file['date_modified'] = json_file['date'].apply(str)

# %%
#date format is yyyymmdd this line changes to yyyy-mm-dd
json_file['date_modified'] = pd.to_datetime(json_file['date'], format='%Y%m%d')

# %%
json_file.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20201113      56  10588169  133262737  12010.0                68516.0
# 1  20201112      56  10417836  132049982  11385.0                67096.0
# 2  20201111      56  10267310  131040557  11287.0                65373.0
# 3  20201110      56  10122811  130048210   8579.0                61964.0
# 4  20201109      56   9991822  129109794  23458.0                59275.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                511397.0         13132.0          26997.0
# 1                507933.0         12796.0          26803.0
# 2                504015.0         12518.0          26584.0
# 3                500692.0         11952.0          26335.0
# 4                496746.0         11533.0          26087.0
#
#    onVentilatorCurrently  ...          lastModified  total posNeg  \
# 0                 3769.0  ...  2020-11-13T24:00:00Z      0      0
# 1                 3622.0  ...  2020-11-12T24:00:00Z      0      0
# 2                 3367.0  ...  2020-11-11T24:00:00Z      0      0
# 3                 3205.0  ...  2020-11-10T24:00:00Z      0      0
# 4                 3110.0  ...  2020-11-09T24:00:00Z      0      0
#
#    deathIncrease  hospitalizedIncrease  negativeIncrease positiveIncrease  \
# 0           1301                  3464           1212755           170333
# 1           1104                  3918           1009425           150526
# 2           1565                  3323            992347           144499
# 3           1347                  3946            938416           130989
# 4            580                  2301           1224702           118708
#
#    totalTestResultsIncrease                                      hash  \
# 0                   1683680  cc4616ee0c98a8684efedbed10805664f0d865f1
# 1                   1490426  e2701845e30d0152936845c12a4297cd916b0582
# 2                   1381858  e55a31c7d307ec4920373ddce73c6337367b20ca
# 3                   1237365  547d47494acfdd4002a96aa3a8f002454bbddd4a
# 4                   1518878  5036a05337f039204f1fb11d603cdb964e8c60c0
#
#    date_modified
# 0     2020-11-13
# 1     2020-11-12
# 2     2020-11-11
# 3     2020-11-10
# 4     2020-11-09
#
# [5 rows x 26 columns]

# %%
json_file.to_json('data_sources/daily_up.json')

# %%
json_file.to_json('data_sources/daily_update.json')

# %%
#out_file = open("national_datas.json", "w")

# %%
#with open('data_sources/national_data.json', 'w') as outfile:
#    json.dump(json_file, outfile)

# %%
# with open('data_sources/national_data.json') as f:
#   data = json.load(f)

# %%
# data

# %%
json_file.to_csv('data_sources/national_data.csv',index = False, header =True)
